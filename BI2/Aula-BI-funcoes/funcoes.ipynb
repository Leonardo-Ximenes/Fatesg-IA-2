# %%
def ola_mundo():
    print("Olá, mundo!")

ola_mundo()
# Out:
# Olá, mundo!

# %%
def funcao_um():
    print("Função um")

funcao_um()
# Out:
# Função um

# %%
def funcao_dois(nome):
    print("Olá %s" %(nome))

# %%
funcao_dois(input("Digite o seu nome"))
# Out:
# Olá leoardo

# %%
def funcao_sequencia():
    for i in range(0,5):
        print("linha" + str(i + 1))

# %%
funcao_sequencia()
# Out:
# linha1
# linha2
# linha3
# linha4
# linha5

# %%
import statistics as st
def notas ():
    n1 = float(input("Digite sua n1: "))
    n2 = float(input("Digite sua n2: "))
    n3 = float(input("Digite sua n3: "))
    
    entradas = (n1,n2,n3)
    media = round(st.mean(entradas),2)

    print(f"sua N1 é {n1}")
    print(f"sua N2 é {n2}")
    print(f"sua N3 é {n3}")
    print(f"sua media é {media}")

    if media < 4:
        print("Você está reprovado")

    elif media < 6:
        print("Você está de recuperação")

    else:
        print("Você está aprovado(a)")

# %%
notas()
# Out:
# sua N1 é 8.0
# sua N2 é 6.0
# sua N3 é 4.0
# sua media é 6.0
# Você está aprovado(a)

# %%
var_global = 10 

def multiplica():
    num1 = int(input("Digite o primeiro numero"))
    num2 = int(input("Digite o segundo numero"))
    var_local = num1 * num2
    print(var_local)

# %%
var_global
# Out:
# 10

# %%
multiplica()
# Out:
# 72
