# %%
import numpy as np
import pandas as pd

# %%
vet = np.array([1,2,3,95,8,45,67,25,35,29,38,65,45,92,9])
vet
# Out:
# array([ 1,  2,  3, 95,  8, 45, 67, 25, 35, 29, 38, 65, 45, 92,  9])

# %%
type(vet)
# Out:
# numpy.ndarray

# %%
vet2 = np.array([1,2,3,4,5])
vet2.cumsum()
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
print(vet[4])
# Out:
# 8

# %%
vet[0] = -1
vet
# Out:
# array([-1,  2,  3, 95,  8, 45, 67, 25, 35, 29, 38, 65, 45, 92,  9])

# %%
vet = np.append(vet,202)
vet
# Out:
# array([ -1,   2,   3,  95,   8,  45,  67,  25,  35,  29,  38,  65,  45,
#         92,   9, 202])

# %%
vet = vet[:-1]
vet
# Out:
# array([-1,  2,  3, 95,  8, 45, 67, 25, 35, 29, 38, 65, 45, 92,  9])

# %%
vet = np.delete(vet,-3)
vet
# Out:
# array([-1,  2,  3, 95,  8, 45, 67, 25, 35, 29, 38, 65, 92,  9])

# %%
vet.shape
# Out:
# (14,)

# %%
vetor = np.array([[0, -5],[11, 300]])
vetor
# Out:
# array([[  0,  -5],
#        [ 11, 300]])

# %%
vetor.shape
# Out:
# (2, 2)

# %%
vetor3x2 = np.array([[1,2],[3,4],[5,6]])
vetor3x2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
vetor2x3 =np.array([[1,2,3],[4,5,6]])
vetor2x3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
vetor2x3.shape
# Out:
# (2, 3)

# %%
y = np.arange(2,200,5)
y
# Out:
# array([  2,   7,  12,  17,  22,  27,  32,  37,  42,  47,  52,  57,  62,
#         67,  72,  77,  82,  87,  92,  97, 102, 107, 112, 117, 122, 127,
#        132, 137, 142, 147, 152, 157, 162, 167, 172, 177, 182, 187, 192,
#        197])

# %%
unicos_vet = np.unique(vet)
unicos_vet
# Out:
# array([-1,  2,  3,  8,  9, 25, 29, 35, 38, 45, 65, 67, 92, 95])

# %%
idadesIA2 = np.array([44,45,23,23,28,19,20,19,17,51,29,28,31,32])
mediaIA2 = round(idadesIA2.mean(),3)
mediaIA2
# Out:
# np.float64(29.214)

# %%
j = np.unique(idadesIA2)
j
# Out:
# array([17, 19, 20, 23, 28, 29, 31, 32, 44, 45, 51])
