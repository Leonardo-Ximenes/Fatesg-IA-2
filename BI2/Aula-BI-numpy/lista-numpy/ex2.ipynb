# %%
#importando biblioteca numpy.

import numpy as np

# %%
#Criando matriz chamada "vetor".
vetor = np.array([[1,2],[3,4],[5,6]])
vetor
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
#Informa as dimensões da matriz.
vetor.shape
# Out:
# (3, 2)

# %%
#Imprimindo a segunda linha da matriz.
vetor[1]
# Out:
# array([3, 4])
